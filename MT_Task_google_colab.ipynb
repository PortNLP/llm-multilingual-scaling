# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## ZeroShot learning for SIB-200 dataset by generating text

from transformers import BloomForCausalLM
from transformers import BloomTokenizerFast
import os
import pandas as pd
import torch
import warnings
from transformers import XGLMTokenizer, XGLMForCausalLM

# %% [markdown]
# ## Zero-Shot

# %%
# model_address = "facebook/xglm-564M"
# model_address = "facebook/xglm-1.7B"
# model_address = "facebook/xglm-2.9B"
model_address = "facebook/xglm-7.5B"


gd_path_input = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/Github Code/"
gd_path_output = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/"

data_directory = gd_path_input + "sib-200/data/annotated"
output_directory = gd_path_output + "MT-Task/sib-200/" + model_address[model_address.find('/')+1:] + "/"

# %%
# Filter out FutureWarning messages
warnings.simplefilter(action='ignore', category=FutureWarning)

if model_address.startswith("facebook"):
    # Load ZeroShot learning model and tokenizer
    model = XGLMForCausalLM.from_pretrained(model_address)
    tokenizer = XGLMTokenizer.from_pretrained(model_address, padding_side='left')
if model_address.startswith("bigscience"):
    # Load ZeroShot learning model and tokenizer
    model = BloomForCausalLM.from_pretrained(model_address)
    tokenizer = BloomTokenizerFast.from_pretrained(model_address)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# XGLMForCausalLM(
#   (model): XGLMModel(
#     (embed_tokens): Embedding(256008, 4096, padding_idx=1)
#     (embed_positions): XGLMSinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0-31): 32 x XGLMDecoderLayer(
#         (self_attn): XGLMAttention(
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=True)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=True)
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=True)
#           (out_proj): Linear(in_features=4096, out_features=4096, bias=True)
#         )
#         (activation_fn): GELUActivation()
#         (self_attn_layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=4096, out_features=16384, bias=True)
#         (fc2): Linear(in_features=16384, out_features=4096, bias=True)
#         (final_layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=4096, out_features=256008, bias=False)
# )

# %%
def translate_batch(texts, input_language, output_language="English", batch_size=32):
    with torch.no_grad():  # Disable gradient calculation
        generated_texts = []
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            prompts = [f"{input_language}: {text} \n{output_language}:" for text in batch_texts]
            inputs = tokenizer(prompts, padding=True, return_tensors="pt").to(device)
            tokens = tokenizer.batch_encode_plus(prompts, add_special_tokens=True, padding=True, return_tensors="pt")['input_ids']
            result_length = tokens.shape[1] + 100
            generated_batch = model.generate(inputs["input_ids"], max_length=result_length)
            for generated_text in generated_batch:
                generated_texts.append(tokenizer.decode(generated_text, skip_special_tokens=True))
            del inputs
            torch.cuda.empty_cache()
    return generated_texts

# def translate(text, input_language, output_language="English"):
#     prompt = f"{input_language}: {text} \n{output_language}:"
#     inputs = tokenizer(prompt, return_tensors="pt").to(device)
#     tokens = tokenizer.encode(prompt, add_special_tokens=True)
#     result_length = len(tokens) + 100
#     generated_text = tokenizer.decode(model.generate(inputs["input_ids"], max_length=result_length)[0])
#     del inputs
#     return generated_text


# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

language_df = pd.read_excel("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/SIB-200 languages - ACL.xlsx")

for index, row in language_df.iterrows():
# for index, row in language_df[:1].iterrows():
    language = row['Language Name']
    folder = row['Folder Name']
    if language == "English":
        continue
    # Initialize an empty DataFrame to store results
    results_df = pd.DataFrame(columns=['text', 'translated_text'])

    subdir = os.path.join(data_directory, folder)

    for file in os.listdir(subdir):
        # Check if the file is a test.tsv file
        if file.endswith("test.tsv"):
            file_path = os.path.join(subdir, file)

            # Check if the output file already exists
            results_file_path = os.path.join(output_directory, f'{folder}.csv')
            if os.path.exists(results_file_path):
                print(f"Output file {results_file_path} already exists. Skipping...")
                continue

            # Read the test.tsv file into a DataFrame
            df = pd.read_csv(file_path, sep='\t')

            # Get all texts from the DataFrame
            texts = df['text'].tolist()

            # Predict translations using your ZeroShot learning model in batches
            generated_texts = translate_batch(texts=texts, input_language=language, batch_size=8)

            # Append the results to the DataFrame
            results_df['text'] = texts
            results_df['translated_text'] = generated_texts

            # Save the results DataFrame to a CSV file in the output directory
            results_file_path = os.path.join(output_directory, f'{folder}.csv')
            results_df.to_csv(results_file_path, index=False)

            print(f"Results saved to {results_file_path}")

# %% [markdown]
# ## Few-shot

# %%
# model_address = "facebook/xglm-564M"
# model_address = "facebook/xglm-1.7B"
model_address = "facebook/xglm-2.9B"
# model_address = "facebook/xglm-7.5B"

n_shot = 2

gd_path_input = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/Github Code/"
gd_path_output = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/"

data_directory = gd_path_input + "sib-200/data/annotated"
output_directory = gd_path_output + f"MT-Task/sib-200/{n_shot}-shot/" + model_address[model_address.find('/')+1:] + "/"

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)

if model_address.startswith("facebook"):
    # Load ZeroShot learning model and tokenizer
    model = XGLMForCausalLM.from_pretrained(model_address)
    tokenizer = XGLMTokenizer.from_pretrained(model_address, padding_side='left')
if model_address.startswith("bigscience"):
    # Load ZeroShot learning model and tokenizer
    model = BloomForCausalLM.from_pretrained(model_address)
    tokenizer = BloomTokenizerFast.from_pretrained(model_address)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device, dtype=torch.bfloat16)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.88G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/276 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.03M [00:00<?, ?B/s]
# XGLMForCausalLM(
#   (model): XGLMModel(
#     (embed_tokens): Embedding(256008, 2048, padding_idx=1)
#     (embed_positions): XGLMSinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0-47): 48 x XGLMDecoderLayer(
#         (self_attn): XGLMAttention(
#           (k_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           (v_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           (out_proj): Linear(in_features=2048, out_features=2048, bias=True)
#         )
#         (activation_fn): GELUActivation()
#         (self_attn_layer_norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=2048, out_features=8192, bias=True)
#         (fc2): Linear(in_features=8192, out_features=2048, bias=True)
#         (final_layer_norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layer_norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=2048, out_features=256008, bias=False)
# )

# %%
def few_shot_maker(input_folder, input_language, output_folder="eng_Latn", output_language="English", n_shots=2):
    # Read the few-shot samples from the input folder
    input_folder_path = os.path.join(data_directory, input_folder)
    output_folder_path = os.path.join(data_directory, output_folder)
    input_df = pd.read_csv(os.path.join(input_folder_path, "train.tsv"), sep='\t')
    output_df = pd.read_csv(os.path.join(output_folder_path, "train.tsv"), sep='\t')
    few_shot = "\n\n".join([f"{input_language}: {input_df['text'][i]} \n{output_language}: {output_df['text'][i]}" for i in range(n_shots)])
    return few_shot

# Function to translate given texts to English
def translate_batch(texts, few_shot_sample, input_language, output_language="English", batch_size=32):
    with torch.no_grad():  # Disable gradient calculation
        generated_texts = []
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            prompts = [f"{few_shot_sample}\n\n{input_language}: {text} \n{output_language}:" for text in batch_texts]
            inputs = tokenizer(prompts, padding=True, return_tensors="pt").to(device)
            tokens = tokenizer.batch_encode_plus(prompts, add_special_tokens=True, padding=True, return_tensors="pt")['input_ids']
            result_length = tokens.shape[1] + 100
            generated_batch = model.generate(inputs["input_ids"], max_length=result_length)
            for generated_text in generated_batch:
                generated_texts.append(tokenizer.decode(generated_text, skip_special_tokens=True))
            del inputs
            torch.cuda.empty_cache()
    return generated_texts

# %%
os.makedirs(output_directory, exist_ok=True)

language_df = pd.read_excel("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/SIB-200 languages - ACL.xlsx")


# Iterate through rows and compare predicted category with actual category
for index, row in language_df.iterrows():
    language = row['Language Name']
    folder = row['Folder Name']
    print(language)
    if language == "English":
        continue
    if f"{folder}.csv" in os.listdir(output_directory):
        continue
    few_shot_sample = few_shot_maker(folder, language, n_shots=n_shot)

    # Initialize an empty DataFrame to store results
    results_df = pd.DataFrame(columns=['text', 'translated_text'])

    subdir = os.path.join(data_directory, folder)
    for file in os.listdir(subdir):
        # Check if the file is a test.tsv file
        if file.endswith("test.tsv"):
            file_path = os.path.join(subdir, file)

            # Check if the file is already present
            results_file_path = os.path.join(output_directory, f'{folder}.csv')
            if os.path.exists(results_file_path):
                print(f"Output file {results_file_path} already exists. Skipping...")
                continue

            # Read the test.tsv file into a DataFrame
            df = pd.read_csv(file_path, sep='\t')

            # Get all texts from the DataFrame
            texts = df['text'].tolist()

            # Predict translations using your ZeroShot learning model in batches
            generated_texts = translate_batch(texts=texts, few_shot_sample=few_shot_sample, input_language=language)

            # Append the results to the DataFrame
            results_df['text'] = texts
            results_df['translated_text'] = generated_texts

            # Save the results DataFrame to a CSV file in the output directory
            results_file_path = os.path.join(output_directory, f'{folder}.csv')
            results_df.to_csv(results_file_path, index=False)

            print(f"Results saved to {results_file_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Awadhi
# Bali
# Bugis
# Central Kurdish
# Southern Sotho
# Fon
# Haitian Creole
# Jingpho
# Rundi
# Northern Kurdish
# Yerwa Kanuri
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/knc_Arab.csv
# Yerwa Kanuri
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/knc_Latn.csv
# Mizo
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lus_Latn.csv
# Magahi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mag_Deva.csv
# Nuer
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/nus_Latn.csv
# Dari
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/prs_Arab.csv
# Bemba
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bem_Latn.csv
# Shan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/shn_Mymr.csv
# Sinhala
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/sin_Sinh.csv
# Slovene
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/slv_Latn.csv
# Jula
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/dyu_Latn.csv
# Nigerian Fulfulde
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/fuv_Latn.csv
# Tamasheq
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/taq_Latn.csv
# Tamasheq
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/taq_Tfng.csv
# Kamba
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kam_Latn.csv
# Kabiyè
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kbp_Latn.csv
# Kimbundu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kmb_Latn.csv
# Luba-Lulua
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lua_Latn.csv
# Waray-Waray
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/war_Latn.csv
# Moore
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mos_Latn.csv
# Umbundu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/umb_Latn.csv
# Aceh
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ace_Arab.csv
# Aceh
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ace_Latn.csv
# tum_Latn
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tum_Latn.csv
# Tosk Albanian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/als_Latn.csv
# Assamese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/asm_Beng.csv
# Asturianu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ast_Latn.csv
# Central Aymara
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ayr_Latn.csv
# South Azerbaijani
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/azb_Arab.csv
# North Azerbaijani
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/azj_Latn.csv
# Bashkort
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bak_Cyrl.csv
# Bamanankan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bam_Latn.csv
# Gikuyu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kik_Latn.csv
# Bhojpuri
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bho_Deva.csv
# Banjar
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bjn_Arab.csv
# Banjar
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bjn_Latn.csv
# Central Tibetan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bod_Tibt.csv
# Akan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/aka_Latn.csv
# Crimean Tatar
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/crh_Latn.csv
# Welsh
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/cym_Latn.csv
# Southwestern Dinka
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/dik_Latn.csv
# Dzongkha
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/dzo_Tibt.csv
# Esperanto
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/epo_Latn.csv
# Tsonga
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tso_Latn.csv
# Faroese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/fao_Latn.csv
# Fijian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/fij_Latn.csv
# Chichewa
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/nya_Latn.csv
# Friulian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/fur_Latn.csv
# West Central Oromo
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/gaz_Latn.csv
# Scottish Gaelic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/gla_Latn.csv
# Guarani
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/grn_Latn.csv
# Gujarati
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/guj_Gujr.csv
# Armenian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/hye_Armn.csv
# Lingala
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lin_Latn.csv
# Ilocano
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ilo_Latn.csv
# Javanese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/jav_Latn.csv
# Kabyle
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kab_Latn.csv
# Northern Sotho
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/nso_Latn.csv
# Kannada
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kan_Knda.csv
# Kashmiri
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kas_Arab.csv
# Kashmiri
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kas_Deva.csv
# Halh Mongolian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/khk_Cyrl.csv
# Khmer
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/khm_Khmr.csv
# Ganda
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lug_Latn.csv
# Kyrgyz
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kir_Cyrl.csv
# Igbo
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ibo_Latn.csv
# Ligurian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lij_Latn.csv
# Limburgish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lim_Latn.csv
# Shona
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/sna_Latn.csv
# Lombard
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lmo_Latn.csv
# Latgalian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ltg_Latn.csv
# Luxembourgish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ltz_Latn.csv
# Maithili
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mai_Deva.csv
# Malayalam
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mal_Mlym.csv
# Minangkabau
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/min_Arab.csv
# Minangkabau
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/min_Latn.csv
# Macedonian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mkd_Cyrl.csv
# Kinyarwanda
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kin_Latn.csv
# Maori
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mri_Latn.csv
# Burmese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mya_Mymr.csv
# Nynorsk
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/nno_Latn.csv
# Bokmål
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/nob_Latn.csv
# Nepali
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/npi_Deva.csv
# Occitan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/oci_Latn.csv
# Odia
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ory_Orya.csv
# Pangasinan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/pag_Latn.csv
# Papiamentu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/pap_Latn.csv
# Southern Pashto
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/pbt_Arab.csv
# Merina Malagasy
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/plt_Latn.csv
# Ayacucho Quechua
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/quy_Latn.csv
# Sango
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/sag_Latn.csv
# Santhali
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/sat_Olck.csv
# Sicilian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/scn_Latn.csv
# Samoan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/smo_Latn.csv
# Sindhi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/snd_Arab.csv
# Somali
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/som_Latn.csv
# Sardinian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/srd_Latn.csv
# Éwé
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ewe_Latn.csv
# Sunda
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/sun_Latn.csv
# Silesian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/szl_Latn.csv
# Tatar
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tat_Cyrl.csv
# Telugu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tel_Telu.csv
# Tajik
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tgk_Cyrl.csv
# Tok Pisin
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tpi_Latn.csv
# Turkmen
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tuk_Latn.csv
# Kongo
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kon_Latn.csv
# Uyghur
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/uig_Arab.csv
# Venetian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/vec_Latn.csv
# Swati
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ssw_Latn.csv
# Eastern Yiddish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ydd_Hebr.csv
# Twi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/twi_Latn.csv
# Amharic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/amh_Ethi.csv
# Irish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/gle_Latn.csv
# Hausa
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/hau_Latn.csv
# Icelandic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/isl_Latn.csv
# Setswana
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tsn_Latn.csv
# Wolof
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/wol_Latn.csv
# Lao
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lao_Laoo.csv
# Xhosa
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/xho_Latn.csv
# Zulu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/zul_Latn.csv
# Marathi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mar_Deva.csv
# Maltese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mlt_Latn.csv
# Yoruba
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/yor_Latn.csv
# Swahili
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/swh_Latn.csv
# Eastern Punjabi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/pan_Guru.csv
# Sanskrit
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/san_Deva.csv
# Tigrigna
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tir_Ethi.csv
# Afrikaans
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/afr_Latn.csv
# Egyptian Spoken Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/arz_Arab.csv
# Belarusian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bel_Cyrl.csv
# Bengali
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ben_Beng.csv
# Bosnian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bos_Latn.csv
# Bulgarian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/bul_Cyrl.csv
# Cebuano
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ceb_Latn.csv
# Danish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/dan_Latn.csv
# Greek
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ell_Grek.csv
# Estonian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/est_Latn.csv
# Galician
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/glg_Latn.csv
# Hebrew
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/heb_Hebr.csv
# Indonesian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ind_Latn.csv
# Georgian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kat_Geor.csv
# Kazakh
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kaz_Cyrl.csv
# Lithuanian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lit_Latn.csv
# Standard Latvian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/lvs_Latn.csv
# Romanian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ron_Latn.csv
# Slovak
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/slk_Latn.csv
# Tamil
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tam_Taml.csv
# Tagalog
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tgl_Latn.csv
# Thai
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tha_Thai.csv
# Ukrainian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ukr_Cyrl.csv
# Urdu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/urd_Arab.csv
# Northern Uzbek
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/uzn_Latn.csv
# Standard Malay
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/zsm_Latn.csv
# Catalan
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/cat_Latn.csv
# Czech
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ces_Latn.csv
# Euskera
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/eus_Latn.csv
# Finnish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/fin_Latn.csv
# Hindi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/hin_Deva.csv
# Croatian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/hrv_Latn.csv
# Hungarian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/hun_Latn.csv
# Italian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ita_Latn.csv
# Korean
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kor_Hang.csv
# Dutch
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/nld_Latn.csv
# Iranian Persian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/pes_Arab.csv
# Polish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/pol_Latn.csv
# Portuguese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/por_Latn.csv
# Russian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/rus_Cyrl.csv
# Serbian
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/srp_Cyrl.csv
# Swedish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/swe_Latn.csv
# Turkish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tur_Latn.csv
# Vietnamese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/vie_Latn.csv
# Standard Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/arb_Arab.csv
# Standard Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/arb_Latn.csv
# Standard German
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/deu_Latn.csv
# English
# French
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/fra_Latn.csv
# Japanese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/jpn_Jpan.csv
# Spanish
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/spa_Latn.csv
# Chinese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/zho_Hans.csv
# Chinese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/zho_Hant.csv
# Mesopotamian Spoken Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/acm_Arab.csv
# Arabic, Ta’izzi-Adeni Spoken
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/acq_Arab.csv
# Tunisian Spoken Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/aeb_Arab.csv
# South Levantine Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ajp_Arab.csv
# Levantine Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/apc_Arab.csv
# Najdi Spoken Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ars_Arab.csv
# Moroccan Spoken Arabic
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/ary_Arab.csv
# Chhattisgarhi
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/hne_Deva.csv
# Kabuverdianu
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/kea_Latn.csv
# Dholuo
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/luo_Latn.csv
# Meitei
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/mni_Beng.csv
# Chokwe
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/cjk_Latn.csv
# Central Atlas Tamazight
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/tzm_Tfng.csv
# Yue Chinese
# Results saved to /content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-Task/sib-200/2-shot/xglm-2.9B/yue_Hant.csv

# %%
# ## FewShot learning for SIB-200 dataset

# from transformers import BloomForCausalLM
# from transformers import BloomTokenizerFast
# import os
# import pandas as pd
# import torch
# import warnings
# from transformers import XGLMTokenizer, XGLMForCausalLM

# %% [markdown]
# ## Evaluation

# %%
# !pip install -q evaluate
# !pip install -q sacrebleu
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 768.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 2.7 MB/s eta 0:00:00

# %%
import nltk.translate.bleu_score as bleu

gd_path = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-task/sib-200"
ref_dir = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/Github Code/sib-200/data/annotated/eng_Latn/test.tsv"
# few_shot_path = "/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/MT-task/sib-200/2-shot/"

language_df = pd.read_excel("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/SIB-200 languages - ACL.xlsx")

# %%
language_df.columns
# Out:
# Index(['Folder Name', 'Language Name', 'ISO 639 - 1', 'ISO 639 - 2 (B)',
#        'ISO 639 - 2 (T)', 'ISO 639 - 3', 'Script (ISO 15924)',
#        'Language Family', 'Population', 'Language Vitality',
#        'Digital Language Support', 'Resource Level',
#        'Bloom Train Data Percentage', 'BLOOMZ Finetune Data',
#        'PolyLM Train Data Percentage', 'XGLM Train Percentage',
#        'XGLM Train Percentage - Upscaled', 'F1 xglm-564M top_logprobs',
#        'F1 xglm-1.7B top_logprobs', 'F1 xglm-2.9B top_logprobs',
#        'F1 xglm-7.5B top_logprobs', 'F1 bloom-560M top_logprobs',
#        'F1 bloom-1b1 top_logprobs', 'F1 bloom-1b7 top_logprobs',
#        'F1 bloom-3b top_logprobs', 'F1 bloom-7b1 top_logprobs',
#        'F1 bloomz-560M generate', 'F1 bloomz-1b1 generate',
#        'F1 bloomz-1b7 generate', 'F1 bloomz-3b generate',
#        'F1 bloomz-7b1 generate', 'F1 bloomz-560m generate 2-shot',
#        'F1 bloomz-1b1 generate 2-shot', 'F1 bloomz-1b7 generate 2-shot',
#        'F1 bloomz-3b generate 2-shot', 'F1 bloomz-7b1 generate 2-shot',
#        'F1 bloom-560m generate 2-shot', 'F1 bloom-1b1 generate 2-shot',
#        'F1 bloom-1b7 generate 2-shot', 'F1 bloom-3b generate 2-shot',
#        'F1 bloom-7b1 generate 2-shot', 'F1 xglm-564M generate 2-shot',
#        'F1 xglm-1.7B generate 2-shot', 'F1 xglm-2.9B generate 2-shot',
#        'F1 xglm-7.5B generate 2-shot', 'F1 bloom-560m generate 4-shot',
#        'xglm-564M scbleu', 'xglm-1.7B scbleu', 'xglm-2.9B scbleu',
#        'xglm-7.5B scbleu', 'bloom-560m scbleu', 'bloom-1b1 scbleu',
#        'bloom-1b7 scbleu', 'bloom-3b scbleu', 'bloom-7b1 scbleu',
#        'bloomz-560m scbleu', 'bloomz-1b1 scbleu', 'bloomz-1b7 scbleu',
#        'bloomz-3b scbleu', 'bloomz-7b1 scbleu', 'xglm-564M scbleu 2s',
#        'xglm-1.7B scbleu 2s', 'xglm-2.9B scbleu 2s', 'xglm-7.5B scbleu 2s',
#        'bloom-560m scbleu 2s', 'bloom-1b1 scbleu 2s', 'bloom-1b7 scbleu 2s',
#        'bloom-3b scbleu 2s', 'bloom-7b1 scbleu 2s', 'bloomz-560m scbleu 2s',
#        'bloomz-1b1 scbleu 2s', 'bloomz-1b7 scbleu 2s', 'bloomz-3b scbleu 2s',
#        'bloomz-7b1 scbleu 2s'],
#       dtype='object')

# %%
import os
import evaluate
import re

sacrebleu = evaluate.load("sacrebleu")
# Out:
# Downloading builder script:   0%|          | 0.00/8.15k [00:00<?, ?B/s]

# %%
# language_df = pd.read_excel("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/SIB-200 languages - ACL.xlsx")

# Function to calculate spBLEU score for a pair of sentences
def calculate_sacrebleu_score(predictions, references):
    print(predictions)
    print(references)
    results = sacrebleu.compute(predictions=predictions,
                                references=references)
    # print(round(results["score"], 1))
    return round(results["score"], 1)

    # reference = reference.split()
    # hypothesis = hypothesis.split()
    # return bleu.sentence_bleu([reference], hypothesis)

# for 2-shot
def extract_text(text):
    occurrences = 0
    for i, char in enumerate(text):
        if text[i:i+8] == "English:":
            occurrences += 1
            if occurrences == 3:
                # Find the index of the newline character
                newline_index = text.find('\n', i)
                if newline_index != -1:
                    return text[i+8:newline_index].strip()
                else:
                    return text[i+8:].strip()
    return ""


# Function to process CSV files in a directory
def process_directory(input_dir, output_dir, n_shot):
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    reference_df = pd.read_csv(ref_dir, sep='\t')

    # Process each CSV file in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.csv'):
            input_file = os.path.join(input_dir, filename)
            output_file = os.path.join(output_dir, filename)

            # Read CSV into DataFrame
            df = pd.read_csv(input_file)

            # Apply text extraction
            # df['extracted_text'] = df['translated_text'].str.extract(r'English: (.*)')
            # df['extracted_text'] = df['translated_text'].str.extract(r'English: (.*)', flags=re.DOTALL)

            if n_shot == "zero-shot":
                # df['extracted_text'] = df['translated_text'].str.extract(r'English:\s*(.*)')
                df['extracted_text'] = df['translated_text'].str.extract(r'English:\s*([^\n]*)')

            elif n_shot == "2-shot":
                df['extracted_text'] = df['translated_text'].apply(extract_text)

            df['extracted_text'] = df['extracted_text'].astype(str)

            df['eng_text'] = reference_df['text']

            predictions = df['extracted_text'].tolist()
            references = df['eng_text'].apply(lambda x: [x]).tolist()

            # results = sacrebleu.compute(predictions=df['extracted_text'].tolist(), references=[df['eng_text'].tolist()])
            results = sacrebleu.compute(predictions=predictions, references=references)
            sacrebleu_score = round(results["score"], 1)

            if n_shot == "zero-shot":
                language_df.loc[language_df['Folder Name'] == filename[:-4], f'{model_name} scbleu'] = sacrebleu_score
            elif n_shot == "2-shot":
                language_df.loc[language_df['Folder Name'] == filename[:-4], f'{model_name} scbleu 2s'] = sacrebleu_score


            # df['sacrebleu_score'] = df.apply(lambda row: calculate_sacrebleu_score([str(row['extracted_text'])], [row['eng_text']]), axis=1)

            # # Save the DataFrame to a new CSV file in the output directory
            # df.to_csv(output_file, index=False)
            # print(f"Saved - {output_file}")




# model_name = "bloom-560m"
# n_shot = "zero-shot"       # 2-shot

# input_directory = f'{gd_path}/{n_shot}/{model_name}/'
# output_directory = f'{gd_path}/{n_shot}_metrics/{model_name}/'
# process_directory(input_directory, output_directory)

# %%
xglm_models = ["xglm-564M", "xglm-1.7B", "xglm-2.9B", "xglm-7.5B"]
bloom_models = ["bloom-560m", "bloom-1b1", "bloom-1b7", "bloom-3b", "bloom-7b1"]
bloomz_models = ["bloomz-560m", "bloomz-1b1", "bloomz-1b7", "bloomz-3b", "bloomz-7b1"]

n_shot = "2-shot"       # 2-shot

for model_name in xglm_models:

    input_directory = f'{gd_path}/{n_shot}/{model_name}/'
    output_directory = f'{gd_path}/{n_shot}_metrics/{model_name}/'
    process_directory(input_directory, output_directory, n_shot)

language_df.to_csv("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/results.csv", index=False)

# %%
n_shot = "2-shot"       # 2-shot

for model_name in bloom_models:

    input_directory = f'{gd_path}/{n_shot}/{model_name}/'
    output_directory = f'{gd_path}/{n_shot}_metrics/{model_name}/'
    process_directory(input_directory, output_directory, n_shot)

# %%
# bloomz_models = ["bloomz-7b1"]
n_shot = "2-shot"       # 2-shot

for model_name in bloomz_models:

    input_directory = f'{gd_path}/{n_shot}/{model_name}/'
    output_directory = f'{gd_path}/{n_shot}_metrics/{model_name}/'
    process_directory(input_directory, output_directory, n_shot)

language_df.to_csv("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/results.csv", index=False)

# %%
# input_directory = f'{gd_path}/{n_shot}/{model_name}/'
# df = pd.read_csv(f"{input_directory}ace_Arab.csv")
# df['extracted_text'] = df['translated_text'].str.extract(r'English:\s*(.*)')
# df['extracted_text'][0]

# %%
# df["translated_text"][0]

# %%
# predictions = ["بوم فيسي جي كرجا ماصل بك ڤرينسيڤ بهوا جي ڤرلو ككواتن ك ڤساڤت اينتي دڠن ڤروتون ڠن نيوترون."]
# references = ["hello there general kenobi"]
# sacrebleu = evaluate.load("sacrebleu")
# results = sacrebleu.compute(predictions=predictions, references=references)

# print(round(results["score"], 1))

# %%
language_df = pd.read_excel("/content/drive/MyDrive/PSU Stuff/NLP Lab/LLM Size and Scalability/SIB-200 languages - ACL.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
